# %%
pip install requests

# %%
pip install bs4

# %%
import requests
from bs4 import BeautifulSoup

# %%
phn_nm = []
phn_pr = []
#phn_rtng_rev =[]



page_num = input("Enter number of pages")
for i in range(1,int(page_num)+1):
    url = "https://www.flipkart.com/search?q=phone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"+str(i)
    req = requests.get(url)
    content = BeautifulSoup(req.content,'html.parser')
    print(content)
    name = content.find_all('div',{"class":"_4rR01T"})
    price = content.find_all('div',{"class":"_30jeq3 _1_WHN1"})
    #rating_review = content.find_all('div',{"class":"gUuXy-"})
    print("Phone  in Page" + str(i))
    print(len(name))
    
    
    for i in name:
        phn_nm.append(i.text)
    for i in price:
        phn_pr.append(i.text)
   # for i in rating_review:
        #phn_rtng_rev.append(i.text)
# Out:
# Enter number of pages1
# <!DOCTYPE html>
# ...

# %%
pip install pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Phone Name":phn_nm, "Phone Price":phn_pr})

# %%
df
# Out:
#                                            Phone Name Phone Price
# 0                      Apple iPhone 15 (Blue, 128 GB)     ₹66,999
# 1                Motorola g54 5G (Pearl Blue, 128 GB)     ₹13,999
# 2               Motorola G34 5G (Ocean Green, 128 GB)     ₹10,999
# 3             Motorola g54 5G (Midnight Blue, 128 GB)     ₹13,999
# 4                   vivo T2x 5G (Aurora Gold, 128 GB)     ₹14,999
# 5                 vivo T2x 5G (Glimmer Black, 128 GB)     ₹12,999
# 6                   vivo T2x 5G (Aurora Gold, 128 GB)     ₹12,999
# 7                   vivo T2x 5G (Marine Blue, 128 GB)     ₹12,999
# 8                   vivo T2x 5G (Marine Blue, 128 GB)     ₹11,999
# 9                   vivo T2x 5G (Marine Blue, 128 GB)     ₹14,999
# 10                  vivo T2x 5G (Aurora Gold, 128 GB)     ₹11,999
# 11                vivo T2x 5G (Glimmer Black, 128 GB)     ₹11,999
# 12                vivo T2x 5G (Glimmer Black, 128 GB)     ₹14,999
# ...

# %%
import csv

# %%
df.to_csv('flipkart.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
phones_df = pd.read_csv('C:/Users/VARSHA/Downloads/flipkart.csv',sep =None,thousands=',',engine='python')

# %%
phones_df
# Out:
#                Title         Colour  Memory(GB)  Price
# 0    OPPO Reno11 5G       Rock Grey         128  29999
# 1       vivo T2x 5G     Aurora Gold         128  12999
# 2       vivo T2x 5G     Aurora Gold         128  14999
# 3       vivo T2x 5G     Marine Blue         128  12999
# 4       vivo T2x 5G   Glimmer Black         128  12999
# ..               ...            ...         ...    ...
# 91  Apple iPhone 14            Blue         128  57999
# 92         POCO C55       Cool Blue         128   7499
# 93  Motorola g54 5G      Pearl Blue         128  13999
# 94         POCO C51     Power Black          64   5699
# 95     Motorola G32    Mineral Gray         128   9999
#
# [96 rows x 4 columns]

# %%
phones_df.shape
# Out:
# (96, 4)

# %%
phones_df.dtypes
# Out:
# Title         object
# Colour        object
# Memory(GB)     int64
# Price          int64
# dtype: object

# %%
phones_df.isnull()
# Out:
#     Title  Colour  Memory(GB)  Price
# 0   False   False       False  False
# 1   False   False       False  False
# 2   False   False       False  False
# 3   False   False       False  False
# 4   False   False       False  False
# ..    ...     ...         ...    ...
# 91  False   False       False  False
# 92  False   False       False  False
# 93  False   False       False  False
# 94  False   False       False  False
# 95  False   False       False  False
#
# [96 rows x 4 columns]

# %%
#there are no missing values
phones_df.index
# Out:
# RangeIndex(start=0, stop=96, step=1)

# %%
phones_df.columns
# Out:
# Index(['Title', 'Colour', 'Memory(GB)', 'Price'], dtype='object')

# %%
phones_df
# Out:
#                Title         Colour  Memory(GB)  Price
# 0    OPPO Reno11 5G       Rock Grey         128  29999
# 1       vivo T2x 5G     Aurora Gold         128  12999
# 2       vivo T2x 5G     Aurora Gold         128  14999
# 3       vivo T2x 5G     Marine Blue         128  12999
# 4       vivo T2x 5G   Glimmer Black         128  12999
# ..               ...            ...         ...    ...
# 91  Apple iPhone 14            Blue         128  57999
# 92         POCO C55       Cool Blue         128   7499
# 93  Motorola g54 5G      Pearl Blue         128  13999
# 94         POCO C51     Power Black          64   5699
# 95     Motorola G32    Mineral Gray         128   9999
#
# [96 rows x 4 columns]

# %% [markdown]
# Best phones based on price lessthan 30000

# %%
phones_df[phones_df.Price<30000]
# Out:
#                Title         Colour  Memory(GB)  Price
# 0    OPPO Reno11 5G       Rock Grey         128  29999
# 1       vivo T2x 5G     Aurora Gold         128  12999
# 2       vivo T2x 5G     Aurora Gold         128  14999
# 3       vivo T2x 5G     Marine Blue         128  12999
# 4       vivo T2x 5G   Glimmer Black         128  12999
# ..               ...            ...         ...    ...
# 90         POCO C55    Forest Green          64   6499
# 92         POCO C55       Cool Blue         128   7499
# 93  Motorola g54 5G      Pearl Blue         128  13999
# 94         POCO C51     Power Black          64   5699
# 95     Motorola G32    Mineral Gray         128   9999
#
# [77 rows x 4 columns]

# %%
phones_df[phones_df.Colour == 'Aurora Gold']
# Out:
#            Title       Colour  Memory(GB)  Price
# 1   vivo T2x 5G   Aurora Gold         128  12999
# 2   vivo T2x 5G   Aurora Gold         128  14999
# 7   vivo T2x 5G   Aurora Gold         128  11999
# 28  vivo T2x 5G   Aurora Gold         128  12999
# 29  vivo T2x 5G   Aurora Gold         128  14999
# 36  vivo T2x 5G   Aurora Gold         128  11999
# 49  vivo T2x 5G   Aurora Gold         128  12999
# 50  vivo T2x 5G   Aurora Gold         128  14999
# 55  vivo T2x 5G   Aurora Gold         128  11999
# 73  vivo T2x 5G   Aurora Gold         128  12999
# 74  vivo T2x 5G   Aurora Gold         128  14999
# 79  vivo T2x 5G   Aurora Gold         128  11999

# %% [markdown]
# Visualizing Basic Analysis of the data using plots

# %%
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#bar plot
plt.figure(figsize=(10,6))
sns.scatterplot(x=phones_df['Title'],y=phones_df['Price'])
plt.title("Title and Price")
# Out:
# Text(0.5, 1.0, 'Title and Price')

# %%
sns.boxplot(x=phones_df['Price'])
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %% [markdown]
# As we can see there is 4 outlier where the price range is very high
